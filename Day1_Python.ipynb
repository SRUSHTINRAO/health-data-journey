# %%
a = 2
b = 4
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 6
# -2
# 0.5
# 8

# %%
names = ["Aria", "Bhadra", "Chia"]
print(names)
print(names[2])
print(names[0:])
print(names[-1])
# Out:
# ['Aria', 'Bhadra', 'Chia']
# Chia
# ['Aria', 'Bhadra', 'Chia']
# Chia

# %%
def maths(a,b):
  return a + b
print(maths(67,54))
# Out:
# 121

# %%
import pandas as pd
data = { "name" : ["Aria", "Bhadra", "Chia"],
        "age" : [23, 45, 67],
         "hobbies" : ["singing", "drawing", "cycling"]}
x = pd.DataFrame(data)
#x.head()
x
# Out:
#      name  age  hobbies
# 0    Aria   23  singing
# 1  Bhadra   45  drawing
# 2    Chia   67  cycling

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
name = ["Aria", "Bhadra", "Chia"]
c = pd.Series(name, index=  ['x','y','z'])
c["y"]
# Out:
# 'Bhadra'

# %%
import pandas as pd
data = {"name1" : "Aria", "name2":"Bhadra", "name3":"Chia"}
x = pd.Series(data, index = ["name1", "name2"])
x
# Out:
# name1      Aria
# name2    Bhadra
# dtype: object

# %%
import pandas as pd
data = { "name" : ["Aria", "Bhadra", "Chia"],
        "age" : [23, 45, 67],
         "hobbies" : ["singing", "drawing", "cycling"]}
x = pd.DataFrame(data, index = ["hobby1","hobby2","hobby3"])
print(x.loc["hobby1"])
# Out:
# name          Aria
# age             23
# hobbies    singing
# Name: hobby1, dtype: object

# %%
import pandas as pd
df = pd.read_csv("job_salary_prediction_dataset.csv")
#df.to_string()
df
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
# ...
